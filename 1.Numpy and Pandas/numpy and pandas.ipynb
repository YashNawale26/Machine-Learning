# %%
import pandas as pd

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
#1
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
#2
df.count()
# Out:
# User ID            400
# Gender             400
# Age                400
# EstimatedSalary    400
# Purchased          400
# dtype: int64

# %%
import pandas as pd
ucdf=pd.read_csv('vehicles.csv');
ucdf.describe();

# %%
print(ucdf.describe());
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %%
#3
print(ucdf.isnull().sum());
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
print((ucdf.isnull().sum())*100/ucdf.shape[0]);
# Out:
# id                0.000000
# url               0.000000
# region            0.000000
# region_url        0.000000
# price             0.000000
# year              0.282281
# manufacturer      4.133714
# model             1.236179
# condition        40.785232
# cylinders        41.622470
# fuel              0.705819
# odometer          1.030735
# title_status      1.930753
# transmission      0.598763
# VIN              37.725356
# drive            30.586347
# size             71.767476
# type             21.752717
# paint_color      30.501078
# image_url         0.015930
# description       0.016398
# county          100.000000
# state             0.000000
# lat               1.534155
# long              1.534155
# posting_date      0.015930
# dtype: float64

# %%
print((ucdf.isna().sum())*100/ucdf.shape[0]);
# Out:
# id                0.000000
# url               0.000000
# region            0.000000
# region_url        0.000000
# price             0.000000
# year              0.282281
# manufacturer      4.133714
# model             1.236179
# condition        40.785232
# cylinders        41.622470
# fuel              0.705819
# odometer          1.030735
# title_status      1.930753
# transmission      0.598763
# VIN              37.725356
# drive            30.586347
# size             71.767476
# type             21.752717
# paint_color      30.501078
# image_url         0.015930
# description       0.016398
# county          100.000000
# state             0.000000
# lat               1.534155
# long              1.534155
# posting_date      0.015930
# dtype: float64

# %%
ucdf2=ucdf.drop(columns=['county']);

# %%
print(ucdf2.describe());
# Out:
#                  id         price           year      odometer            lat  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05  420331.000000
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04      38.493940
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05       5.841533
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     -84.122245
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04      34.601900
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04      39.150100
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05      42.398900
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07      82.390818
#
#                 long
# count  420331.000000
# mean      -94.748599
# std        18.365462
# min      -159.827728
# 25%      -111.939847
# 50%       -88.432600
# 75%       -80.832039
# max       173.885502

# %%
print(ucdf.describe());
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %%
hdf=pd.read_csv('home_data.csv');
hdf.describe();

# %%
print(hdf.describe());
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
print(hdf.shape);
# Out:
# (21613, 21)

# %%
hdf.shape;

# %%
print(hdf.columns);
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
print(hdf.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
print(hdf.head(10))
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900         3       1.00         1180
# 1  6414100192  20141209T000000   538000         3       2.25         2570
# 2  5631500400  20150225T000000   180000         2       1.00          770
# 3  2487200875  20141209T000000   604000         4       3.00         1960
# 4  1954400510  20150218T000000   510000         3       2.00         1680
# 5  7237550310  20140512T000000  1225000         4       4.50         5420
# 6  1321400060  20140627T000000   257500         3       2.25         1715
# 7  2008000270  20150115T000000   291850         3       1.50         1060
# 8  2414600126  20150415T000000   229500         3       1.00         1780
# 9  3793500160  20150312T000000   323000         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
print(hdf.tail(10))
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 21603  7852140040  20140825T000000   507250         3       2.50         2270
# 21604  9834201367  20150126T000000   429000         3       2.00         1490
# 21605  3448900210  20141014T000000   610685         4       2.50         2520
# 21606  7936000429  20150326T000000  1007500         4       3.50         3510
# 21607  2997800021  20150219T000000   475000         3       2.50         1310
# 21608   263000018  20140521T000000   360000         3       2.50         1530
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
# 21610  1523300141  20140623T000000   402101         2       0.75         1020
# 21611   291310100  20150116T000000   400000         3       2.50         1600
# 21612  1523300157  20141015T000000   325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
print(hdf['floors']>1)
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 21608     True
# 21609     True
# 21610     True
# 21611     True
# 21612     True
# Name: floors, Length: 21613, dtype: bool

# %%
hdf[hdf['floors']>=1.5]
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 6      1321400060  20140627T000000  257500         3       2.25         1715
# 9      3793500160  20150312T000000  323000         3       2.50         1890
# 12      114101516  20140528T000000  310000         3       1.00         1430
# 14     1175000570  20150312T000000  530000         5       2.00         1810
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
print(hdf[hdf['yr_built']<1968]);
print(hdf[hdf['yr_built']<1968].shape);
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 7      2008000270  20150115T000000  291850         3       1.50         1060
# ...           ...              ...     ...       ...        ...          ...
# 21303   522059130  20150429T000000  465000         3       1.00         1150
# 21332  9266700190  20150511T000000  245000         1       1.00          390
# 21343  2924079034  20140925T000000  332220         3       1.50         2580
# 21470   121039156  20150109T000000  249000         3       1.00         1030
# 21583  2025049203  20140610T000000  399950         2       1.00          710
#
# ...

# %%
print(hdf[hdf['price']>50000]);
print(hdf[hdf['price']>50000].shape);
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
print(hdf[(hdf['bedrooms']<=2)& (hdf['price']>51000)])
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 11     9212900260  20140527T000000  468000         2       1.00         1160
# 18       16000397  20141205T000000  189000         2       1.00         1200
# 23     8091400200  20140516T000000  252700         2       1.50         1070
# 31     2426039314  20141201T000000  280000         2       1.50         1190
# ...           ...              ...     ...       ...        ...          ...
# 21586  2767604724  20141015T000000  505000         2       2.50         1430
# 21588  2767600688  20141113T000000  414500         2       1.50         1210
# 21595  1972201967  20141031T000000  520000         2       2.25         1530
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
print(hdf[hdf['bedrooms']>2])
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# ...           ...              ...      ...       ...        ...          ...
# 21606  7936000429  20150326T000000  1007500         4       3.50         3510
# 21607  2997800021  20150219T000000   475000         3       2.50         1310
# 21608   263000018  20140521T000000   360000         3       2.50         1530
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
# 21611   291310100  20150116T000000   400000         3       2.50         1600
#
# ...

# %%
hdf.isnull().count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
hdf.dropna(inplace=True)

# %%
hdf['bedrooms'].fillna(hdf['bedrooms'].mean(),inplace=True)
hdf['bedrooms']
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
hdf2=hdf.copy()
hdf2.rename(columns={'sqft_living':'sqft_liv','sqft_basement':'sqft_bsment','yr_renovated':'yr_ren'},inplace=True)

# %%
hdf2.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_liv', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_bsment', 'yr_built', 'yr_ren', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
hdf2=hdf2.drop(['date','view','condition'],axis=1)
hdf2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hdf2=hdf2.drop(['date','view','condition'],axis=1)
#       2 hdf2.columns
#
# NameError: name 'hdf2' is not defined

# %%
hdf2.describe()
# Out:
#                  id         price      bedrooms     bathrooms      sqft_liv  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront         grade    sqft_above  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      7.656873   1788.390691
# ...

# %%
hdf2.mode()
# Out:
#             id     price  bedrooms  bathrooms  sqft_liv  sqft_lot  floors  \
# 0  795000620.0  350000.0       3.0        2.5    1300.0    5000.0     1.0
# 1          NaN  450000.0       NaN        NaN       NaN       NaN     NaN
# 2          NaN       NaN       NaN        NaN       NaN       NaN     NaN
# 3          NaN       NaN       NaN        NaN       NaN       NaN     NaN
#
#    waterfront  grade  sqft_above  sqft_bsment  yr_built  yr_ren  zipcode  \
# 0         0.0    7.0      1300.0          0.0    2014.0     0.0  98103.0
# 1         NaN    NaN         NaN          NaN       NaN     NaN      NaN
# 2         NaN    NaN         NaN          NaN       NaN     NaN      NaN
# 3         NaN    NaN         NaN          NaN       NaN     NaN      NaN
#
#        lat    long  sqft_living15  sqft_lot15
# 0  47.5322 -122.29         1540.0      5000.0
# 1  47.5491     NaN            NaN         NaN
# 2  47.6624     NaN            NaN         NaN
# ...

# %%
hdf2.nunique()
# Out:
# id               21436
# price             4032
# bedrooms            13
# bathrooms           30
# sqft_liv          1038
# sqft_lot          9782
# floors               6
# waterfront           2
# grade               12
# sqft_above         946
# sqft_bsment        306
# yr_built           116
# yr_ren              70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
hdf2['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
print(hdf2.quantiles([0,0.25,0.5,0.75,1]));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_704\3113805009.py in ?()
# ----> 1 print(hdf2.quantiles([0,0.25,0.5,0.75,1]));
#
# D:\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'quantiles'

# %%
hdf2.mean
# Out:
# <bound method DataFrame.mean of                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...
